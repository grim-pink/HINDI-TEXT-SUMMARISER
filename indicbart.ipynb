# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Hindi_train.csv'

df_train = pd.read_csv(file_path)

# %%
new_df = df_train[df_train['Id'].str.startswith("hindi_2023_train")].copy()

# %%
len(new_df)
# Out:
# 9857

# %%
df_without_ids = new_df.drop('Id',axis=1)
df = df_without_ids.drop_duplicates()

# %%
from sklearn.model_selection import train_test_split
train, val = train_test_split(new_df, test_size=0.2)

# %%
train.shape
# Out:
# (7885, 4)

# %%
# !pip install transformers datasets evaluate torch rouge_score
# !pip install rouge bert_score
# !pip install accelerate -U

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq
from datasets import load_dataset, Dataset, DatasetDict, load_metric
import numpy as np
import pandas as pd

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_dataset = Dataset.from_pandas(train)
val_dataset = Dataset.from_pandas(val)
dataset = DatasetDict({'train': train_dataset, 'validation': val_dataset})

tokenizer = AutoTokenizer.from_pretrained("ai4bharat/IndicBART")
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/IndicBART").to(device)

def map_to_model_inputs(batch):
    inputs = tokenizer(batch['Article'], padding='max_length', truncation=True, max_length=1024)
    outputs = tokenizer(batch['Summary'], padding='max_length', truncation=True, max_length=100)
    batch['input_ids'] = inputs.input_ids
    batch['attention_mask'] = inputs.attention_mask
    batch['labels'] = outputs.input_ids
    batch['labels'] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] for labels in batch['labels']]
    return batch

tokenized_dataset = dataset.map(map_to_model_inputs, batched=True)

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    rouge = load_metric('rouge')
    bert_score = load_metric('bertscore')

    rouge_output = rouge.compute(predictions=decoded_preds, references=decoded_labels, rouge_types=["rougeL", "rouge2"])
    bert_score_output = bert_score.compute(predictions=decoded_preds, references=decoded_labels, lang="hi")

    return {
        "rouge2": rouge_output['rouge2'].mid.fmeasure,
        "rougeL": rouge_output['rougeL'].mid.fmeasure,
        "bert_score": bert_score_output['f1'][0]
    }

training_args = Seq2SeqTrainingArguments(
    output_dir='./results',
    evaluation_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    weight_decay=0.005,
    save_total_limit=1,
    num_train_epochs=3,
    predict_with_generate=True,
    gradient_accumulation_steps = 16
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset['train'],
    eval_dataset=tokenized_dataset['validation'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

trainer.train()

model.save_pretrained('/content/drive/MyDrive/indicBART_finetuned_small')
tokenizer.save_pretrained('/content/drive/MyDrive/indicBART_finetuned_small')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/832 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.90M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/221 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/398 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# pytorch_model.bin:   0%|          | 0.00/976M [00:00<?, ?B/s]
# Map:   0%|          | 0/7885 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1972 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='369' max='369' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [369/369 1:01:45, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Bert Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>2.211058</td>
#       <td>0.033776</td>
#       <td>0.113670</td>
#       <td>0.585170</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.111071</td>
#       <td>0.038102</td>
#       <td>0.125792</td>
#       <td>0.632604</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>2.083808</td>
#       <td>0.038499</td>
#       <td>0.126537</td>
#       <td>0.658022</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1141: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# <ipython-input-14-390df5a64e59>:39: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric('rouge')
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for bertscore contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/bertscore/bertscore.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.92k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1141: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for bertscore contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/bertscore/bertscore.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1141: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for bertscore contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/bertscore/bertscore.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'forced_eos_token_id': 2}
# ('/content/drive/MyDrive/indicBART_finetuned_small/tokenizer_config.json',
#  '/content/drive/MyDrive/indicBART_finetuned_small/special_tokens_map.json',
#  '/content/drive/MyDrive/indicBART_finetuned_small/spiece.model',
#  '/content/drive/MyDrive/indicBART_finetuned_small/added_tokens.json',
#  '/content/drive/MyDrive/indicBART_finetuned_small/tokenizer.json')

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model='/content/drive/MyDrive/indicBART_finetuned_small', tokenizer="/content/drive/MyDrive/indicBART_finetuned_small")

text = """मानसून सीजन में हुई भारी बारिश ने कई राज्यों में भारी तबाही मचाई है। हिमाचल प्रदेश में पिछले 40 दिनों में 187 लोगों की जान जा चुकी है, वहीं 34 लोग लापता हैं।
तेलंगाना में एक हफ्ते में 18 लोगों की मौत हो गई। करीब 12,000 लोगों को राहत शिविरों में पहुंचाया गया है।
उधर, शनिवार को जम्मू-कश्मीर के गांदरबल जिले के एक गांव में बादल फट गया। जिससे सात घर, एक मस्जिद और दो स्कूल क्षतिग्रस्त हो गए।
उत्तराखंड के चमोली में रविवार सुबह पहाड़ों से पत्थर गिरने के बाद बद्रीनाथ नेशनल हाईवे को बंद करना पड़ा। हालांकि, 2 घंटे बाद हाईवे ट्रैफिक के लिए खोल दिया गया।
अगले 24 घंटे कैसे रहेंगे…
इन राज्यों में तेज बारिश होगी: हिमाचल, महाराष्ट्र, उत्तराखंड, उत्तर प्रदेश, राजस्थान, मध्यप्रदेश, बिहार, झारखंड, गोवा, छत्तीसगढ़, ओडिशा, पश्चिम बंगाल, असम, अरुणाचल प्रदेश।
बारिश की संभावना नहीं: जम्मू-कश्मीर, पंजाब, हरियाणा, पश्चिमी राजस्थान, गुजरात, कर्नाटक, आंध्र प्रदेश, केरल, तमिलनाडु में बारिश की संभावना नहीं है।
अलग-अलग राज्यों से मानसून की तस्वीरें...
अन्य राज्यों में मौसम का हाल..."""
print(summarizer(text))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1141: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'summary_text': 'मानसून सीजन में हुई भारी बारिश ने कई राज्यों में भारी तबाही मचाई है। हिमाचल प्रदेश'}]

# %%
from transformers import pipeline
from datasets import load_metric
from bert_score import score as bert_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

summarizer = pipeline("summarization", model="/content/drive/MyDrive/indicBART_finetuned_small", tokenizer="/content/drive/MyDrive/indicBART_finetuned_small")

rouge = load_metric("rouge")


def compute_metrics(generated_summary, reference_summary):
    rouge_scores = rouge.compute(predictions=[generated_summary], references=[reference_summary])
    rouge_scores = {key: value.mid.fmeasure * 100 for key, value in rouge_scores.items()}
    _, _, bertscore_f1 = bert_score([generated_summary], [reference_summary], lang="hi", rescale_with_baseline=False)
    metrics = {k: round(v, 4) for k, v in rouge_scores.items()}
    metrics['bert_score_f1'] = round(bertscore_f1.mean().item() * 100, 4)
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([generated_summary, reference_summary])
    cosine_sim = cosine_similarity(vectors[0:1], vectors[1:])
    metrics['cosine_similarity'] = round(cosine_sim[0][0] * 100, 4)
    return metrics
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# <ipython-input-3-c8ba9c0ae127>:11: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
for index, row in val.iterrows():
    try:
        print(f"Processing Article {index}: {str(row['Article'])[:50]}")

        generated_summaries = summarizer(row["Article"], max_length=75, min_length=30, length_penalty=2.0, num_beams=4)

        if len(generated_summaries) > 0:
            generated_summary = generated_summaries[0]['summary_text']
            metrics = compute_metrics(generated_summary, row["Summary"])

            print(f"Article {index}:")
            print(f"Generated Summary: {generated_summary}")
            print(f"Reference Summary: {row['Summary']}")
            print(f"Metrics: {metrics}")
            print("\n---\n")
        else:
            print(f"No summary generated for Article {index}.")

    except Exception as e:
        print(f"An error occurred at Article {index}: {e}")
# Out:
# Processing Article 567: सरकारी नौकरी की तलाश कर रहे बेरोजगारों के लिए अच्छ
# Article 567:
# Generated Summary: 留 Rajasthan Government Jobs Recruitment 2018: सरकारी नौकरी की तलाश कर रहे बेरोजगारों के लिए अच्छी खबर है। नेशनल टेस्टिंग एजेंसी ने देशभर में एकलव्य मॉडल रेजिडेंशियल स्कूल में 6 हजार से ज्यादा पदों पर वैकेंसी निकाली है। इसके तहत टीचिंग और नॉन टीचिंग पदों पर भर्तियां की जाएंगी। भर्ती प्रक्रिया
# Reference Summary: Eklavya Model Residential Schools Vacancy Details Update; Government job vacancy teaching and non-teaching positions  भर्ती प्रक्रिया में शामिल होने के लिए उम्मीदवार एकलव्य मॉडल रेजिडेंशियल स्कूल की ऑफिशल वेबसाइट emrs.tribal.gov.in पर जाकर 18 अगस्त तक ऑनलाइन अप्लाई कर सकते हैं।
# Metrics: {'rouge1': 7.6923, 'rouge2': 0.0, 'rougeL': 7.6923, 'rougeLsum': 7.6923, 'bert_score_f1': 68.5345, 'cosine_similarity': 18.9896}
#
# ---
#
# Processing Article 9829: महाराष्ट्र के पालघर में एक कार ड्राइवर ट्रैफिक पुल
# Article 9829:
# Generated Summary: पालघर में एक कार ड्राइवर ट्रैफिक पुलिस कॉन्स्टेबल को गाड़ी के बोनट पर 1 किमी तक लेकर घूमता रहा। बाद में कार ड्राइवर को गिरफ्तार कर लिया गया। कार चालक के पास लाइसेंस नहीं था, इसीलिए वह कार्रवाई से बचने के लिए भाग रहा था। आरोपी को गिरफ्तार कर उस पर हत्या के प्रयास का केस दर्ज किया गया है। घटना का वीडियो सोशल
# Reference Summary: Car driver drove 1km with constable on bonnet in Maharashtra, महाराष्ट्र के पालघर में एक कार ड्राइवर ट्रैफिक पुलिस कांस्टेबल को गाड़ी के बोनट पर 1 किमी तक लेकर घूमता रहा।
# Metrics: {'rouge1': 16.6667, 'rouge2': 0.0, 'rougeL': 16.6667, 'rougeLsum': 16.6667, 'bert_score_f1': 74.1579, 'cosine_similarity': 30.8714}
#
# ---
#
# Processing Article 3087: हिमाचल प्रदेश में आज से वेस्टर्न डिस्टरबेंस फिर सक
# Article 3087:
# Generated Summary: बिलासपुर हिमाचल प्रदेश में आज से वेस्टर्न डिस्टरबेंस फिर सक्रिय होगा। मौसम विज्ञान केंद्र शिमला ने भारी बारिश व ओलावृष्टि का येलो अलर्ट जारी किया है। आज भी प्रदेश के कुछेक स्थानों पर तेज बारिश हो सकती है। मगर, कल व परसों प्रदेश के ज्यादातर भागों में ओलावृष्टि और तेज बारिश का पूर्वानुमान है। 13
# Reference Summary: Himachal Weather forecast हिमाचल प्रदेश में आज से वेस्टर्न डिस्टरबेंस फिर सक्रिय होगा। मौसम विज्ञान केंद्र शिमला ने भारी बारिश व ओलावृष्टि का येलो अलर्ट जारी किया है। आज भी प्रदेश के कुछेक स्थानों पर तेज बारिश हो सकती है।
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 87.9479, 'cosine_similarity': 68.0289}
#
# ---
#
# Processing Article 1181: ‘जिसकी आंखों में मेरी ही नमी हो कोई तो है वो यार म
# An error occurred at Article 1181: index out of range in self
# Processing Article 7277: हाल ही में डायरेक्टर अयान मुखर्जी ने अपनी अपकमिंग
# Article 7277:
# Generated Summary: ་ Actor Ayushmann Khurrana on Twitter. हाल ही में डायरेक्टर अयान मुखर्जी ने अपनी अपकमिंग फिल्म ‘ब्रह्मास्त्र 2’ और ‘ब्रह्मास्त्र 3’ के बारे में जानकारी शेयर की है। अयान ने बताया कि इस बार वो ‘ब्रह्मास्त्र’ के दोनों पार्ट की शूटिंग एक साथ करेंगे। उन्होंने ये भी कहा कि इस
# Reference Summary: Bollywood Direcor Ayan Mukerji Brahmastra Movie Shooting - हाल ही में डायरेक्टर अयान मुखर्जी ने अपनी अपकमिंग फिल्म ‘ब्रह्मास्त्र 2’ और ‘ब्रह्मास्त्र 3’ के बारे में जानकारी शेयर की है। अयान ने बताया कि इस बार वो ‘ब्रह्मास्त्र’ के दोनों पार्ट की शूटिंग एक साथ करेंगे
# Metrics: {'rouge1': 25.0, 'rouge2': 14.2857, 'rougeL': 25.0, 'rougeLsum': 25.0, 'bert_score_f1': 92.7153, 'cosine_similarity': 66.1927}
#
# ---
#
# Processing Article 7415: म्यांमार में सैन्य सरकार जुंटा ने आंग सान सू की की
# An error occurred at Article 7415: index out of range in self
# Processing Article 8822: बॉलीवुड एक्टर रणबीर कपूर इन दिनों अपनी अपकमिंग फिल
# Article 8822:
# Generated Summary: Actor Ranbir Kapoor, Bollywood Actress Alia Bhatt, Bollywood Actor Ranbir Kapoor, Bollywood एक्टर Ranbir Kapoor इन दिनों अपनी अपकमिंग फिल्म 'तू झूठी मैं मक्कार' का लगातार प्रमोशन कर रहे हैं। अब हाल ही में एक्टर श्रद्धा कपूर के साथ सिंगिग रियलिटी शो इंडियन आइडल 13 में पहुंचे, जहां उन्होंने बेटी राहा को लेकर भी बात की है।
# Reference Summary: Ranbir Kapoor Upcoming film Tu Jhoothi ​​Main Makkar Movie Promotion At Indian Idol 13  मुझे इस बात का डर नहीं है कि मेरी दाढ़ी उसे चुभेगी, लेकिन मुझे डर है कि मेरे शेव करने के बाद शायद मुझे वह पहचान न पाए।
# Metrics: {'rouge1': 20.6897, 'rouge2': 7.4074, 'rougeL': 20.6897, 'rougeLsum': 20.6897, 'bert_score_f1': 66.9684, 'cosine_similarity': 9.8874}
#
# ---
#
# Processing Article 7495: चेन्नई सुपर किंग्स की टीम IPL से पहले प्रैक्टिस के
# Article 7495:
# Generated Summary: 留 CSK Vs CSK - CSK Vs CSK - CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK Vs CSK
# Reference Summary: IPL Chennai Super Kings Captain MS Dhoni has been practicing at Chepauk Stadium. Follow Indian Premier League (IPL) Latest News Updates On Dainik Bhaskar IPL शुरू होने से पहले चेन्नई सुपर किंग्स के कप्तान एमएस धोनी पिछले कुछ दिनों से चेन्नई के चेपॉक स्टेडियम में प्रैक्टिस कर रहे है।
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 50.2596, 'cosine_similarity': 0.0}
#
# ---
#
# Processing Article 6680: बॉलीवुड एक्ट्रेस दीपिका पादुकोण इन दिनों भूटान में
# Article 6680:
# Generated Summary: गौरतलब है कि बॉलीवुड एक्ट्रेस दीपिका पादुकोण इन दिनों भूटान में हैं। जिसकी कुछ फोटोज दीपिका के फैन पेज ने सोशल मीडिया अकाउंट पर शेयर की हैं। इन फोटोज में दीपिका वहां पर मौजूद अपने फैंस के साथ सेल्फी लेते हुई नजर आईं। भूटान के एक कैफे ने दीपिका के साथ फोटो शेयर की हैं, जिसमें वह अपने फैंस के साथ सेल्फी लेती हुई नजर
# Reference Summary: भूटान पहुंचीं दीपिका पादुकोण, Seen in no makeup look, clicked selfie with fans
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 64.5091, 'cosine_similarity': 0.0}
#
# ---
#
# Processing Article 1348: अफ्रीकी देश केन्या में एक ऐसा गांव है; जहां कोई पु
# An error occurred at Article 1348: index out of range in self
# Processing Article 6133: ‘मेरी हाइट 5.2 इंच है। छोटे कद और लुक की वजह से मु
# An error occurred at Article 6133: index out of range in self
# Processing Article 8702: तीन साल बाद बुक फेयर हो रहा था। तो जाना लाजिमी था,
# An error occurred at Article 8702: index out of range in self
# Processing Article 8682: बिलासपुर में एक हैरान कर देने वाला मामला सामने आया
# Article 8682:
# Generated Summary: 留 बिलासपुर में एक हैरान कर देने वाला मामला सामने आया है। नकली नोट के अवैध कारोबार में लगे एक युवक के घर पर जब पुलिस ने छापा मारा तो नकली नोट, नोट छापने वाली मशीन के साथ ही वहां एक टंकी में महिला की 6 टुकड़ों में की गई लाश मिली। यह लाश पानी की टंकी में रखी हुई थी। आरोपी ने बताया,
# Reference Summary: Chhattisgarh Bilaspur Murder Case - बिलासपुर में एक हैरान कर देने वाला मामला सामने आया है। नकली नोट के अवैध कारोबार में लगे एक युवक के घर पर जब पुलिस ने छापा मारा तो नकली नोट, नोट छापने वाली मशीन के साथ ही वहां एक टंकी में महिला की 6 टुकड़ों
# Metrics: {'rouge1': 33.3333, 'rouge2': 0.0, 'rougeL': 33.3333, 'rougeLsum': 33.3333, 'bert_score_f1': 87.03, 'cosine_similarity': 72.0688}
#
# ---
#
# Processing Article 9272: फिल्म स्टार नवाजुद्दीन सिद्दीकी पर उनकी पत्नी आलिय
# An error occurred at Article 9272: index out of range in self
# Processing Article 1444: फिल्म 72 हूरें सिनेमाघरों में आ गई है। फिल्म की रि
# An error occurred at Article 1444: index out of range in self
# Processing Article 1030: महाराष्ट्र के डिप्टी सीएम अजित पवार शुक्रवार को NC
# Article 1030:
# Generated Summary: 達 Maharashtra Deputy Chief Minister Ajit Pawar NCP President Sharad Pawar meets NCP President Sharad Pawar on Maharashtra Governor Anil Baijal's residence. महाराष्ट्र के डिप्टी सीएम अजित पवार शुक्रवार को NCP प्रमुख शरद पवार से मिलने उनके घर पहुंचे। अजित पवार के महाराष्ट्र सरकार में शामिल होने के बाद दोनों की यह पहली मुलाकात है। इस मुलाकात से जुड़ी कोई ठोस जानकारी अभी तक सामने
# Reference Summary: Maharashtra Cabinet Expansion Update; Ajit Pawar Finance Ministry, Bhujbal Gets Food and Civil Supplies महाराष्ट्र में NCP के 9 मंत्रियों को विभागों का बंटवारा कर दिया गया है। डिप्टी CM अजित पवार को वित्त और योजना विभाग का मंत्री बनाया गया है। वहीं छगन भुजबल को खाद्य और नागरिक आपूर्ति विभाग सौंपा गया है।
# Metrics: {'rouge1': 20.0, 'rouge2': 5.2632, 'rougeL': 20.0, 'rougeLsum': 20.0, 'bert_score_f1': 67.781, 'cosine_similarity': 18.1156}
#
# ---
#
# Processing Article 1677: हांगझोऊ एशियन गेम्स से पहले भारतीय जूडो टीम में डो
# Article 1677:
# Generated Summary: 為 Indian जूडो टीम में डोपिंग का बड़ा मामला सामने आया है। टीम के 5 खिलाड़ी डोप टेस्ट में फेल हो गए हैं। अंग्रेजी अखबार न्यू इंडियन एक्सप्रेस ने दावा किया है कि 4 अप्रैल को दिल्ली के इंदिरा गांधी स्टेडियम में आयोजित ट्रायल्स में इन सभी के सैपल लिए गए हैं। जिनकी जांच रिपोर्ट अब आई है। रिपोर्ट आने के बाद 5 खिलाड़ियों
# Reference Summary: Hangzhou Asian Games 2023 - Indian Judo Team 5 Players Fail Dope Test In Delhi. हांगझोऊ एशियन गेम्स से पहले भारतीय जूडो टीम में डोपिंग का बड़ा मामला सामने आया है। टीम के 5 खिलाड़ी डोप टेस्ट में फेल हो गए हैं
# Metrics: {'rouge1': 31.5789, 'rouge2': 0.0, 'rougeL': 31.5789, 'rougeLsum': 31.5789, 'bert_score_f1': 75.6462, 'cosine_similarity': 20.193}
#
# ---
#
# Processing Article 3834: 10 टीमें, 70+ मैच और 52 दिन का महासमर...IPL 2023।
# An error occurred at Article 3834: index out of range in self
# Processing Article 8703: कांग्रेस इस बार राजस्थान में सरकार रिपीट करने के द
# An error occurred at Article 8703: index out of range in self
# Processing Article 2544: राजस्थान कैडर में तैनात युवा IAS अफसर रिया डाबी ने
# An error occurred at Article 2544: index out of range in self
# Processing Article 8922: बॉर्डर सिक्योरिटी फोर्स (BSF) की तरफ से पंजाब के अ
# Article 8922:
# Generated Summary: बॉर्डर सिक्योरिटी फोर्स (BSF) की तरफ से पंजाब के अमृतसर बॉर्डर पर गिराए गए एक ड्रोन की स्टडी ने देश को हिला दिया है। दो महीने बाद ड्रोन की फोरेंसिक रिपोर्ट से पता चला है कि भारत-पाकिस्तान सीमा पर गिराया गया ड्रोन पहले चाइना में और फिर पाकिस्तान में भी उड़ान भर चुका था। गौरतलब है कि BSF ने 25 दिसंबर की
# Reference Summary: BSF Shot Down Drone Forensic Report | India Pakistan Border Report about China too बॉर्डर सिक्योरिटी फोर्स (BSF) की तरफ से पंजाब के अमृतसर बॉर्डर पर गिराए गए एक ड्रोन की स्टडी ने देश को हिला दिया है।
# Metrics: {'rouge1': 23.5294, 'rouge2': 0.0, 'rougeL': 23.5294, 'rougeLsum': 23.5294, 'bert_score_f1': 78.3517, 'cosine_similarity': 37.068}
#
# ---
#
# Processing Article 9393: बॉलीवुड एक्टर रणबीर कपूर इन दिनों अपनी अपकमिंग फिल
# Article 9393:
# Generated Summary: गौरतलब है कि बॉलीवुड एक्टर रणबीर कपूर इन दिनों अपनी अपकमिंग फिल्म एनिमल को लेकर सुर्खियों में बने हुए हैं। फिल्म की शूटिंग पूरी हो चुकी है। इसी बीच रणबीर का एक वीडियो सोशल मीडिया पर सामने आया है। इस वीडियो में रणबीर अपनी हिट फिल्मों में से एक दिल्ली वाली गर्लफ्रेंड गाने पर डांस करते हुए नजर आ रहे हैं। इसके अलावा उन्होंने काफी
# Reference Summary: Watch Ranbir Kapoor Groove to Iconic Bollywood Songs बॉलीवुड एक्टर रणबीर कपूर इन दिनों अपनी अपकमिंग फिल्म एनिमल को लेकर सुर्खियों में बने हुए हैं।
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 75.7041, 'cosine_similarity': 37.0696}
#
# ---
#
# Processing Article 2622: वक्त के साथ सोने-चांदी के गहनों की चमक फीकी पड़ जा
# Article 2622:
# Generated Summary: 留 सोने के गहनों की चमक फीकी पड़ जाती है। इन्हें साफ कराने के लिए हम सुनार के पास जाते हैं। कई बार इन गहनों को चमकाने के नाम पर सुनार ठगी भी कर लेते हैं। जिसके बारे में ज्यादातर लोगों को पता भी नहीं चल पाता है। आज जरूरत की खबर में हम जानेंगे घर बैठे आसानी से गहनों
# Reference Summary: Jewellery Cleaning Tips - How To Clean Gold, Silver Jewellery At Home Easily ? All You Need To Know. सोने-चांदी के गहनों और बर्तनों को ऐसी चीजों से साफ करने की ट्रिक्स बताते हैं जिसके लिए यूज होने वाला सारा सामान आपको घर में ही मिल जाएगा।
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 67.3008, 'cosine_similarity': 7.793}
#
# ---
#
# Processing Article 9322: 2015 में आतंकी संगठन ISIS में शामिल होने गईं ब्रिट
# Article 9322:
# Generated Summary: 留 UK Consulate On Indian Women Sexual Harassment - 2015 में आतंकी संगठन ISIS में शामिल होने गईं ब्रिटिश नागरिक शमीमा बेगम दोबारा नागरिकता हासिल करने का केस हार गईं। ब्रिटेन की एक अदालत ने बुधवार को कहा कि शमीमा की ब्रिटिश सिटीजनशिप छीनने का होम डिपार्टमेंट का फैसला सही था, इस पर रोक नहीं लगाई जाएगी। शमीमा
# Reference Summary: Shamima Begum loses British citizenship appeal 015 में आतंकी संगठन ISIS में शामिल होने गईं ब्रिटिश नागरिक शमीमा बेगम दोबारा नागरिकता हासिल करने का केस हार गईं।
# Metrics: {'rouge1': 11.7647, 'rouge2': 0.0, 'rougeL': 11.7647, 'rougeLsum': 11.7647, 'bert_score_f1': 79.5605, 'cosine_similarity': 38.275}
#
# ---
#
# Processing Article 6281: उर्वशी रौतेला को हाल ही में मुंबई एयरपोर्ट पर स्पॉ
# Article 6281:
# Generated Summary: एक्ट्रेस उर्वशी रौतेला को हाल ही में मुंबई एयरपोर्ट पर स्पॉट किया गया, इसका एक विडियो सोशल मीडिया पर सामने आया है। वीडियो में उर्वशी एयरपोर्ट पर डांस करती हुई नजर आईं। इस दौरान उन्होंने रेड ड्रेस पहनी हुई है। इसी के साथ उर्वशी ने चेहरे पर मास्क और ब्लैक गॉगल्स लगा रखा है। वीडियो
# Reference Summary: Urvashi Rautela spotted dancing at Mumbai Airport in a red dress उर्वशी रौतेला को हाल ही में मुंबई एयरपोर्ट पर स्पॉट किया गया, इसका एक विडियो सोशल मीडिया पर सामने आया है।
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 78.3738, 'cosine_similarity': 47.4936}
#
# ---
#
# Processing Article 7411: जहानाबाद में बिना हेलमेट बाइक चला रहा युवक (23) पु
# Article 7411:
# Generated Summary: 留 जहानाबाद में बिना हेलमेट बाइक चला रहा युवक (23) पुलिस चेकिंग देखकर भागा तो ASI ने उसका पीछा किया और गोली मार दी। घटना मंगलवार की है। युवक की हालत गंभीर बताई जा रही है। गोली मारने वाले ASI मुमताज अहमद को पुलिस ने गिरफ्तार कर लिया गया है। उसके ऊपर हत्या की कोशिश का केस दर्ज किया गया है।
# Reference Summary: ASI Ahmed Arrested for Firing at Biker During Bihar Police Helmet Checking जहानाबाद में बिना हेलमेट बाइक चला रहा युवक (27) पुलिस चेकिंग देखकर भागा तो ASI ने 4 किलोमीटर तक उसका पीछा किया और गोली मार दी। घटना मंगलवार की
# Metrics: {'rouge1': 22.2222, 'rouge2': 0.0, 'rougeL': 22.2222, 'rougeLsum': 22.2222, 'bert_score_f1': 76.7349, 'cosine_similarity': 37.6344}
#
# ---
#
# Processing Article 2967: आज (बुधवार, 14 जून) आषाढ़ मास के कृष्ण पक्ष की एका
# Article 2967:
# Generated Summary: 達 आज (बुधवार, 14 जून) आषाढ़ मास के कृष्ण पक्ष की एकादशी है। इसका नाम योगिनी एकादशी है। इस तिथि पर भगवान विष्णु की पूजा और व्रत करने की परंपरा है। मान्यता है कि जो लोग योगिनी एकादशी का व्रत करते हैं, उन्हें भगवान विष्णु और देवी लक्ष्मी की कृपा मिलती है, घर-परिवार में सुख-समृद्धि बनी
# Reference Summary: आज (बुधवार, 14 जून) आषाढ़ मास के कृष्ण पक्ष की एकादशी है। इसका नाम योगिनी एकादशी है। इस तिथि पर भगवान विष्णु की पूजा और व्रत करने की परंपरा है। yogini ekadashi on 14th June, significance of ekadashi vrat, yogini ekadashi story in hindi
# Metrics: {'rouge1': 12.5, 'rouge2': 0.0, 'rougeL': 12.5, 'rougeLsum': 12.5, 'bert_score_f1': 87.0279, 'cosine_similarity': 53.8052}
#
# ---
#
# Processing Article 3626: पूर्व CJI रंजन गोगोई के खिलाफ दाखिल 1 करोड़ की मान
# Article 3626:
# Generated Summary: 達 पूर्व CJI रंजन गोगोई के खिलाफ दाखिल 1 करोड़ की मानहानि केस में आज दार्जिलिंग की कोर्ट में सुनवाई होगी। यह केस पूर्व CJI की आत्मकथा 'जस्टिस फॉर द जज' से जुड़ा है। दरअसल, असम के एक NGO के अध्यक्ष अभिजीत शर्मा ने दावा किया था कि रंजन गोगोई की आत्मकथा में नेशनल रजिस्टर ऑफ सिटजिन
# Reference Summary: Prayagraj (Allahabad) High Court Manglik Girl Rape Case Update; Sexual Intercourse Based On Promise To Marry Is ... यह आदेश जस्टिस बृज राज सिंह की कोर्ट ने दिया था। इस मामले की अगली सुनवाई 26 जून, 2023 को होनी थी
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 65.465, 'cosine_similarity': 5.2204}
#
# ---
#
# Processing Article 5357: IPL 2023 में मुंबाई इंडियंस (MI) की जीत की दुआ करन
# Article 5357:
# Generated Summary: आईपीएल 2023 में मुंबाई इंडियंस (MI) की जीत की दुआ करने के लिए देश के सबसे अमीर व्यक्ति रिलायंस ग्रुप के मालिक मुकेश अंबानी की पत्नी नीता अंबानी बुधवार देर रात गोल्डन टेंपल पहुंची। अपनी टीम MI की जर्सी पहन वह गोल्डन टेंपल परिसर में दाखिल हुईं। नीता अंबानी ने उस समय गोल्डन टेंपल में माथा टेक
# Reference Summary: Nita Ambani Visits Golden Temple, Offers Prayers for Mumbai Indians: Punjab Kings Defeated at Their Home Ground IPL 2023 में मुंबाई इंडियंस (MI) की जीत की दुआ करने के लिए देश के सबसे अमीर व्यक्ति रिलायंस ग्रुप के मालिक मुकेश अंबानी की पत्नी नीता अंबानी बुधवार देर रात गोल्डन टेंपल पहुंची।
# Metrics: {'rouge1': 17.3913, 'rouge2': 9.5238, 'rougeL': 17.3913, 'rougeLsum': 17.3913, 'bert_score_f1': 80.8814, 'cosine_similarity': 33.2446}
#
# ---
#
# Processing Article 1120: “नौकरी करने जाती है कि यहां-वहां घूमने,” घर में घु
# An error occurred at Article 1120: index out of range in self
# Processing Article 780: बहुत से काम हैं! आओ, बंजर जमीन पर घास फैला दें। पे
# An error occurred at Article 780: index out of range in self
# Processing Article 6282: रॉयल चैलेंजर्स बेंगलुरु (RCB) के स्टार बल्लेबाज वि
# Article 6282:
# Generated Summary: बेंगलुरू रॉयल चैलेंजर्स बेंगलुरु (RCB) के स्टार बल्लेबाज विराट कोहली पर मैच फीस का 10% जुर्माना लगाया गया है। कोहली पर इंडियन प्रीमियर लीग (IPL) आचार संहिता के उल्लंघन के लिए यह जुर्माना लगाया गया है। IPL के बयान में कहा गया कि कोहली ने IPL की आचार संहिता के अनुच्छेद 2.2 के तहत नियमों का उल्लंघन किया है। बयान में हालांकि
# Reference Summary: IPL RCB Cvs CSK Match; Virat Kohli Fined 10% of Match Fee for Breaching IPL Code of Conduct रॉयल चैलेंजर्स बेंगलुरु (RCB) के स्टार बल्लेबाज विराट कोहली पर मैच फीस का 10% जुर्माना लगाया गया है। कोहली पर इंडियन प्रीमियर लीग (IPL) आचार संहिता के उल्लंघन के लिए यह जुर्माना लगाया गया है।
# Metrics: {'rouge1': 35.7143, 'rouge2': 15.3846, 'rougeL': 28.5714, 'rougeLsum': 28.5714, 'bert_score_f1': 79.992, 'cosine_similarity': 61.3126}
#
# ---
#
# Processing Article 3135: इन दिनों सोशल मीडिया पर मेट्रो में दो महिलाओं की ल
# An error occurred at Article 3135: index out of range in self
# Processing Article 7895: पंजाब की कैटरीना कैफ यानी शहनाज गिल अक्सर अपने चुल
# Article 7895:
# Generated Summary: ་ Bollywood Actress Katrina Kaif Latest News Update पंजाब की कैटरीना कैफ यानी शहनाज गिल अक्सर अपने चुलबुले अंदाज से फैंस का दिल जीत ही लेती हैं। इन दिनों वह अपना शो 'देसी वाइब्स विद शहनाज गिल' को लेकर चर्चा में बनी हुई हैं। उनके इस शो में कई बड़ी हस्तियां शामिल हो
# Reference Summary: Desi Vibes With Shehnaaz Gill; Bollywood Actress Sara Ali Khan at  Shehnaaz Gill's chat show पंजाब की कैटरीना कैफ यानी शहनाज गिल अक्सर अपने चुलबुले अंदाज से फैंस का दिल जीत ही लेती हैं।
# Metrics: {'rouge1': 17.3913, 'rouge2': 9.5238, 'rougeL': 17.3913, 'rougeLsum': 17.3913, 'bert_score_f1': 81.8263, 'cosine_similarity': 22.964}
#
# ---
#
# Processing Article 6675: राजस्थान में पिछले 7 साल से ट्रांसफर का इंतजार कर
# Article 6675:
# Generated Summary: 留 Rajasthan Government Recruitment - राजस्थान में पिछले 7 साल से ट्रांसफर का इंतजार कर रहे ग्रेड थर्ड टीचर्स को जल्द राहत मिल सकती है। मुख्यमंत्री अशोक गहलोत की अध्यक्षता में आज होने वाली कैबिनेट बैठक में नई ट्रांसफर पॉलिसी पर चर्चा की जाएगी। ऐसे में माना जा रहा है कि चुनावी साल में तबादलों से बैन हटने के बाद जुलाई तक टीचर्
# Reference Summary: Ashok Gehlot (Rajasthan) Govt Cabinet Meeting Today - राजस्थान में पिछले 7 साल से ट्रांसफर का इंतजार कर रहे ग्रेड थर्ड टीचर्स को जल्द राहत मिल सकती है। मुख्यमंत्री अशोक गहलोत की अध्यक्षता में आज होने वाली कैबिनेट बैठक में नई ट्रांसफर पॉलिसी पर चर्चा की जाएगी
# Metrics: {'rouge1': 33.3333, 'rouge2': 0.0, 'rougeL': 33.3333, 'rougeLsum': 33.3333, 'bert_score_f1': 87.981, 'cosine_similarity': 70.2255}
#
# ---
#
# Processing Article 9337: बेंगलुरु की इलेक्ट्रिक स्टार्ट-अप कंपनी रिवर ने अप
# Article 9337:
# Generated Summary: 留 बेंगलुरु की इलेक्ट्रिक स्टार्ट-अप कंपनी रिवर ने अपना नया इलेक्ट्रिक स्कूटर 'इंडी'(Indie) लॉन्च किया है। ये स्कूटर फुल चार्ज 120 किलोमीटर तक की राइडिंग रेंज ( इको मोड पर) देगा। इस इलेक्ट्रिक स्कूटर की शुरुआती कीमत 1.25 लाख रुपए (एक्स-शोरूम) रखी गई है। मिलेगी दमदार बैटरी रिवर ने अपने
# Reference Summary: River Indie Electric Scooter Launched in India  बेंगलुरु की इलेक्ट्रिक स्टार्ट-अप कंपनी रिवर ने अपना नया इलेक्ट्रिक स्कूटर 'इंडी'(Indie) लॉन्च किया है। ये स्कूटर फुल चार्ज 120 किलोमीटर तक की राइडिंग रेंज ( इको मोड पर) देगा
# Metrics: {'rouge1': 30.7692, 'rouge2': 18.1818, 'rougeL': 30.7692, 'rougeLsum': 30.7692, 'bert_score_f1': 84.834, 'cosine_similarity': 68.2682}
#
# ---
#
# Processing Article 4854: नमस्कार,
# द केरला स्टोरी फिल्म न दिखाए जाने पर सुप
# An error occurred at Article 4854: index out of range in self
# Processing Article 566: यूक्रेन जंग के बीच गुरुवार को रूस ने ओडेसा शहर पर
# Article 566:
# Generated Summary: 留 Ukraine war: यूक्रेन जंग के बीच गुरुवार को रूस ने ओडेसा शहर पर हमला किया, जिसमें 3 लोगों की मौत हो गई। रॉयटर्स के मुताबिक, इस हमले में चीन के कॉन्सुलेट ऑफिस को भी नुकसान पहुंचा है। ओडेसा के गवर्नर ने बिल्डिंग की एक तस्वीर पोस्ट की जिसमें एक खिड़की टूटी नजर आ रही
# Reference Summary: Russia Ukraine War Photos Update;  यूक्रेन के राष्ट्रपति जेलेंस्की ने बताया था कि एक पोर्ट सिटी पर रूस के हमले में चीन को भेजने के लिए रखा 60 हजार टन कृषि उत्पाद (अनाज) नष्ट हो गया
# Metrics: {'rouge1': 44.4444, 'rouge2': 28.5714, 'rougeL': 44.4444, 'rougeLsum': 44.4444, 'bert_score_f1': 69.3003, 'cosine_similarity': 17.2366}
#
# ---
#
# Processing Article 1353: चेन्नई के इंदिरा नगर स्टेशन में लोकल ट्रेन से गिरन
# Article 1353:
# Generated Summary: 為 Chennai Chennai Express train accident: चेन्नई के इंदिरा नगर स्टेशन में लोकल ट्रेन से गिरने के कारण एक महिला की मौत हो गई। मरने वाली महिला ट्रेन के फुटबोर्ड पर खड़े होकर फोन पर बात कर रही थी। जब चोरों ने उसका मोबाइल छीनने की कोशिश की तो वह प्लेटफॉर्म पर गिर गई। घटना 2 जुलाई की है, जबकि सिर पर लगी चोट
# Reference Summary: Chennai's Indira Nagar station Case - चेन्नई में एक महिला की मोबाइल फोन चुराने की कोशिश कर रहे दो लोगों द्वारा हमला किए जाने के बाद ट्रेन से गिरकर मौत हो गई। घटना पिछले हफ्ते की है. हालांकि, शनिवार को उसने दम तोड़ दिया
# Metrics: {'rouge1': 16.6667, 'rouge2': 0.0, 'rougeL': 16.6667, 'rougeLsum': 16.6667, 'bert_score_f1': 77.3005, 'cosine_similarity': 27.4876}
#
# ---
#
# Processing Article 677: डच राजधानी एम्स्टर्डम में वेश्यालय को शहर से बाहर
# An error occurred at Article 677: index out of range in self
# Processing Article 9256: दिवालिया होने की कगार पर खड़े पाकिस्तान ने अपने कर
# Article 9256:
# Generated Summary: 留 Pakistan Rescue Forces (PDF) - दिवालिया होने की कगार पर खड़े पाकिस्तान ने अपने करीबी मुस्लिम दोस्त तुर्किये के साथ बड़ा फरेब किया। हाल ही में पाकिस्तान सरकार ने तुर्किये के भूकंप पीड़ितों को कुछ मदद भेजी थी। खास बात यह है कि यह वही रिलीफ मटैरियल था जो पिछले साल पाकिस्तान में
# Reference Summary: Pakistan Flood Victims Aid Vs Turkey Earthquake Aid दिवालिया होने की कगार पर खड़े पाकिस्तान ने अपने करीबी मुस्लिम दोस्त तुर्किये के साथ बड़ा फरेब किया।
# Metrics: {'rouge1': 16.6667, 'rouge2': 0.0, 'rougeL': 16.6667, 'rougeLsum': 16.6667, 'bert_score_f1': 79.6714, 'cosine_similarity': 27.1509}
#
# ---
#
# Processing Article 929: सोशल मीडिया प्लेटफॉर्म ट्विटर अभी भी घाटे की कंपनी
# Article 929:
# Generated Summary: ་ Twitter Inc. सोशल मीडिया प्लेटफॉर्म ट्विटर अभी भी घाटे की कंपनी बनी हुई है। इस बात की जानकारी खुद कंपनी के मालिक एलन मस्क ने दी। मस्क ने एक ट्वीट का जवाब देते हुए कहा, 'एडवरटाइजिंग रेवेन्यू में लगभग 50% की गिरावट और ज्यादा लोन के कारण कंपनी का कैश फ्लो अभी भी निगेटिव बना हुआ है
# Reference Summary: सोशल मीडिया प्लेटफॉर्म ट्विटर अभी भी घाटे की कंपनी बनी हुई है। इस बात की जानकारी खुद कंपनी के मालिक एलन मस्क ने दी। मस्क ने एक ट्वीट का जवाब देते हुए कहा,'एडवरटाइजिंग रेवेन्यू में लगभग 50% की गिरावट और ज्यादा लोन के कारण कंपनी
# Metrics: {'rouge1': 50.0, 'rouge2': 0.0, 'rougeL': 50.0, 'rougeLsum': 50.0, 'bert_score_f1': 93.8454, 'cosine_similarity': 92.6195}
#
# ---
#
# Processing Article 5279: भारत के मौसम विभाग यानी IMD के मुताबिक, 24 घंटों म
# Article 5279:
# Generated Summary: 留 India Meteorological Department (IMD) has predicted heavy rainfall in the past 24 hours. भारत के मौसम विभाग यानी IMD के मुताबिक, 24 घंटों में केरल समेत 3 राज्यों में भारी बारिश की आशंका है। 13 राज्यों में हल्की से मध्यम बारिश होने का अलर्ट जारी किया गया है। जम्मू कश्मीर और हिमालय के कुछ इलाकों में बर्फबारी होने की संभावना
# Reference Summary: Weather Latest News Update; [Aaj Ka Mausam Kaisa Rahega] - MD - India Meteorological Department Weather Forecast  भारत के मौसम विभाग यानी IMD के मुताबिक, 24 घंटों में 3 राज्यों में भारी बारिश की आशंका है। 13 राज्यों में हल्की से मध्यम बारिश होने का अलर्ट जारी किया गया है
# Metrics: {'rouge1': 38.8889, 'rouge2': 29.4118, 'rougeL': 38.8889, 'rougeLsum': 38.8889, 'bert_score_f1': 81.1921, 'cosine_similarity': 35.0173}
#
# ---
#
# Processing Article 2951: भारतीय कुश्ती संघ (WFI) के चुनाव 6 जुलाई को होंगे।
# Article 2951:
# Generated Summary: 留 Indian कुश्ती संघ (WFI) के चुनाव 6 जुलाई को होंगे। पहले चुनाव 4 जुलाई को होने थे, लेकिन अब इन्हें 2 दिन आगे टाल दिया गया है। इसके लिए नियुक्त रिटर्निंग ऑफिसर पूर्व चीफ जस्टिस मित्तल कुमार ने अधिसूचना जारी कर दी है। चुनाव 15 पदों अध्यक्ष, वरिष्ठ उपाध्यक्ष, उपाध्यक्ष-4 महासचिव, कोषाध्यक्ष, संयुक्त सचिव-2 और कार्यकारिणी
# Reference Summary: Brij Bhushan Sharan Singh Wrestlers Case Update; भारतीय कुश्ती संघ (WFI) के चुनाव 6 जुलाई को होंगे। पहले चुनाव 4 जुलाई को होने थे, लेकिन अब इन्हें 2 दिन आगे टाल दिया गया है। इसके लिए नियुक्त रिटर्निंग ऑफिसर पूर्व चीफ जस्टिस मित्तल कुमार ने अधिसूचना जारी कर दी है।
# Metrics: {'rouge1': 42.1053, 'rouge2': 35.2941, 'rougeL': 42.1053, 'rougeLsum': 42.1053, 'bert_score_f1': 81.6446, 'cosine_similarity': 29.5718}
#
# ---
#
# Processing Article 5082: आज यानी मंगलवार (9 मई) को शेयर बाजार में सपाट कारो
# Article 5082:
# Generated Summary: 留 BSE Sensex Today Stock Market Update - आज यानी मंगलवार (9 मई) को शेयर बाजार में सपाट कारोबार रहा। सेंसेक्स 2 अंक की गिरावट के साथ 61,761 के स्तर पर बंद हुआ। वहीं निफ्टी में महज 1 अंक की तेजी रही, ये 18,265 के स्तर पर बंद हुआ। सेंसेक्स के 30 शेयरों में से 19 में बढ़त और सिर्फ
# Reference Summary: BSE NSE Sensex Today, Stock Market Latest Updates;  हिंडनबर्गकी रिपोर्ट आने के बाद से ही अडाणी ग्रुप लगातार निवेशकों को भरोसा जीतने की कोशिशों में लगा हुआ है।
# Metrics: {'rouge1': 43.4783, 'rouge2': 28.5714, 'rougeL': 43.4783, 'rougeLsum': 43.4783, 'bert_score_f1': 67.7025, 'cosine_similarity': 10.5943}
#
# ---
#
# Processing Article 1592: अरसे से चले रहे ट्रेड वॉर में चीन ने अमेरिका को बड
# Article 1592:
# Generated Summary: मंगलवार को चीन ने अमेरिका को बड़ा झटका दिया है। चीन ने चिप बनाने में इस्तेमाल होने वाली दो धातुओं के एक्सपोर्ट पर प्रतिबंध लगा दिया है. चीन ने चिप बनाने में इस्तेमाल होने वाली दो धातुओं के एक्सपोर्ट पर प्रतिबंध लगा दिया है. इस फैसले से दुनिया के तमाम देशों की चिंता बढ़ गई है। आज स्पॉटलाइट में जानेंगे चीन के फैसले
# Reference Summary: US China Trade War - How does the US-China trade war affect other countries? and What is the impact of US-China trade war on India?  All You Need To Know. चीन के फैसले का भारत पर क्या असर पड़ेगा. और चिप मार्केट क्यों दुनिया के तमाम देशों के लिए जंग का नया मैदान साबित हो रहा है.
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 67.2829, 'cosine_similarity': 6.9522}
#
# ---
#
# Processing Article 8708: इंडियन प्रीमियर लीग का 16वां सीजन 31 मार्च से शुरू
# Article 8708:
# Generated Summary: 為 Indian प्रीमियर लीग का 16वां सीजन 31 मार्च से शुरू होने जा रहा है। अहमदाबाद के प्रधानमंत्री नरेंद्र मोदी स्टेडियम में डिफेंडिंग चैंपियन गुजरात टाइटंस और चेन्नई सुपरकिंग्स के हाई वोल्टेज मुकाबले के साथ लीग की शुरुआत होगी। 41 साल के महेंद्र सिंह धोनी ने इस मुकाबले की तैयारी भी शुरू कर दी है। एयरपोर्ट पर हुआ शानदार वेलकम इससे पहले महेंद्र
# Reference Summary: Mahendra Singh IPL 16th Season Practice Video - चेन्नई सुपर किंग्स के कप्तान महेंद्र सिंह IPL के 16वें सीजन की तैयारी में जुट गए हैं। IPL 31 मार्च से शुरू होगा। सभी फ्रेंचाइजियों ने विभिन्न शहरों में कैंप लगाए हैं। जिनमें अधिकांश भारतीय खिलाड़ी भाग ले रहे हैं।
# Metrics: {'rouge1': 26.6667, 'rouge2': 0.0, 'rougeL': 26.6667, 'rougeLsum': 26.6667, 'bert_score_f1': 69.5421, 'cosine_similarity': 16.1103}
#
# ---
#
# Processing Article 8481: बॉलीवुड स्टार संजय दत्त गुरुवार की देर रात हरियाणा
# Article 8481:
# Generated Summary: गौरतलब है कि बॉलीवुड स्टार संजय दत्त गुरुवार की देर रात हरियाणा के रेवाड़ी स्थित गांव किशनगढ़ बालावास में पहुंचे। यहां अपने पुराने दोस्त हितेन्द्र के घर पहुंचकर उनके पिता की मौत पर दुख जताया। संजय दत्त को देखने के लिए गांव में प्रशंसकों की काफी भीड़ उमड़ी। हालांकि गांव में लोकल पुलिस के अलावा उनकी प्राइवेट सिक्योरिटी भी मौजूद रही। ब्रेन हेम
# Reference Summary: Bollywood Actor Sanjay Dutt Visited Rewari (Haryana) - बॉलीवुड स्टार संजय दत्त गुरुवार की देर रात हरियाणा के रेवाड़ी स्थित गांव किशनगढ़ बालावास में पहुंचे। यहां अपने पुराने दोस्त हितेन्द्र के घर पहुंचकर उनके पिता की मौत पर दुख जताया
# Metrics: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0, 'bert_score_f1': 80.1863, 'cosine_similarity': 47.6252}
#
# ---
#
# Processing Article 8531: गर्मी ने दस्तक दे दी है। आप सभी ने विंटर वियर को स
# An error occurred at Article 8531: index out of range in self
# Processing Article 1165: सेंसर बोर्ड ने फिल्म OMG 2 की रिलीज पर फिलहाल रोक
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d1e81fd14b97> in <cell line: 1>()
#      10             generated_summary = generated_summaries[0]['summary_text']
#      11             # Compute metrics
# ---> 12             metrics = compute_metrics(generated_summary, row["Summary"])
#      13
#      14             # Print or store the metrics as needed
#
# <ipython-input-16-0780d499f47a> in compute_metrics(generated_summary, reference_summary)
#      15 def compute_metrics(generated_summary, reference_summary):
#      16     # Compute ROUGE scores
# ---> 17     rouge_scores = rouge.compute(predictions=[generated_summary], references=[reference_summary])
#      18     # Simplify ROUGE scores to just use mid F-measure
#      19     rouge_scores = {key: value.mid.fmeasure * 100 for key, value in rouge_scores.items()}
#
# /usr/local/lib/python3.10/dist-packages/datasets/metric.py in compute(self, predictions, references, **kwargs)
#     453             inputs = {input_name: self.data[input_name] for input_name in self.features}
#     454             with temp_seed(self.seed):
# --> 455                 output = self._compute(**inputs, **compute_kwargs)
#     456
#     457             if self.buf_writer is not None:
#
# ~/.cache/huggingface/modules/datasets_modules/metrics/rouge/457c405cab0bd19db749b46bf15a1a3cff4d54f50e7ab868c293e5ece288425e/rouge.py in _compute(self, predictions, references, rouge_types, use_aggregator, use_stemmer)
#     122
#     123         if use_aggregator:
# --> 124             result = aggregator.aggregate()
#     125         else:
#     126             result = {}
#
# /usr/local/lib/python3.10/dist-packages/rouge_score/scoring.py in aggregate(self)
#     122       score_matrix = np.vstack(tuple(scores))
#     123       # Percentiles are returned as (interval, measure).
# --> 124       percentiles = self._bootstrap_resample(score_matrix)
#     125       # Extract the three intervals (low, mid, high).
#     126       intervals = tuple(
#
# /usr/local/lib/python3.10/dist-packages/rouge_score/scoring.py in _bootstrap_resample(self, matrix)
#     150           np.arange(matrix.shape[0]), size=matrix.shape[0])
#     151       sample = matrix[sample_idx, :]
# --> 152       sample_mean[i, :] = np.mean(sample, axis=0)
#     153
#     154     # Take percentiles on the estimate of the mean using bootstrap samples.
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3502             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3503
# -> 3504     return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                           out=out, **kwargs)
#    3506
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     118     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     119     if isinstance(ret, mu.ndarray):
# --> 120         with _no_nep50_warning():
#     121             ret = um.true_divide(
#     122                     ret, rcount, out=ret, casting='unsafe', subok=False)
#
# /usr/lib/python3.10/contextlib.py in __enter__(self)
#     128     """Helper for @contextmanager decorator."""
#     129
# --> 130     def __enter__(self):
#     131         # do not keep args and kwds alive unnecessarily
#     132         # they are only needed for recreation, which is not possible anymore
#
# KeyboardInterrupt:

# %%
import numpy as np

rouge1_scores = []
rouge2_scores = []
rougeL_scores = []
bert_scores = []
cosine_similarities = []

test = val[:150]

for index, row in test.iterrows():
    try:
        generated_summaries = summarizer(row["Article"], max_length=80, min_length=30, length_penalty=2.0, num_beams=4)
        if generated_summaries:
            generated_summary = generated_summaries[0]['summary_text']
            metrics = compute_metrics(generated_summary, row["Summary"])

            rouge1_scores.append(metrics['rouge1'])
            rouge2_scores.append(metrics['rouge2'])
            rougeL_scores.append(metrics['rougeL'])
            bert_scores.append(metrics['bert_score_f1'])
            cosine_similarities.append(metrics['cosine_similarity'])
        else:
            print(f"Article {index} produced no summaries.")

    except Exception as e:
        print()

average_rouge1 = np.mean([score for score in rouge1_scores if score > 0])
average_rouge2 = np.mean([score for score in rouge2_scores if score > 0])
average_rougeL = np.mean([score for score in rougeL_scores if score > 0])
average_bert = np.mean([score for score in bert_scores if score > 0])
average_cosine_similarity = np.mean([score for score in cosine_similarities if score > 0])

print(f"Average ROUGE-1: {average_rouge1:.2f}")
print(f"Average ROUGE-2: {average_rouge2:.2f}")
print(f"Average ROUGE-L: {average_rougeL:.2f}")
print(f"Average BERT Score F1: {average_bert:.2f}")
print(f"Average Cosine Similarity: {average_cosine_similarity:.2f}")
# Out:
# Average ROUGE-1: 28.82
# Average ROUGE-2: 23.89
# Average ROUGE-L: 27.46
# Average BERT Score F1: 76.88
# Average Cosine Similarity: 37.90
